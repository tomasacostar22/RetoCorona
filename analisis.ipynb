# %% [markdown]
# Importación de las librerías necesarias

# %%
import pandas as pd
import numpy as np
print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.3
# 2.2.4

# %%
base1 = pd.read_csv("datos_reto_verificado/base_1_transaccional.txt", sep="\t")
base1.head()
# Out:
#         fecha  pedido  id  edad             municipio        zona    asesor  \
# 0  1971-04-30       2   2    52  EL CARMEN DE CHUCURI   SANTANDER  asesor_2
# 1  1971-04-30       3   3    31            VILLANUEVA  LA GUAJIRA  asesor_3
# 2  1971-04-30       4   4    43            VILLANUEVA  LA GUAJIRA  asesor_4
# 3  1971-04-30       5   5    31            VILLANUEVA  LA GUAJIRA  asesor_5
# 4  1971-04-30       6   6    49           ARROYOHONDO     BOLÍVAR  asesor_6
#
#   punto de venta           cluster    categoria_macro    categoria  \
# 0  punto_venta_2  cluster_tienda_2  categoria_macro_1  categoria_2
# 1  punto_venta_2  cluster_tienda_2  categoria_macro_2  categoria_3
# 2  punto_venta_2  cluster_tienda_2  categoria_macro_3  categoria_4
# 3  punto_venta_3  cluster_tienda_3  categoria_macro_2  categoria_5
# 4  punto_venta_4  cluster_tienda_2  categoria_macro_4  categoria_6
#
#      subcategoria    producto          color  cantidad  precio  valor  \
# ...
